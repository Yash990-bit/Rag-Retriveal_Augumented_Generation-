# %% [markdown]
# # Why Vector Store ?
#
# Socho tumhare paas 10,000 chunks hain.
#
# Chunk 1,
# Chunk 2,
# Chunk 3
# ...
# Chunk 10000
#
# User poochta hai:
#
# Leave policy kya hai?
#
# Ab kya AI 10,000 chunks ko ek-ek karke padhega?
#
# ❌ Bahut slow
#
# ❌ Bahut expensive
#
# ❌ Practical nahi
#
# Vector Store ka kaam hai:
#
# # Relevant information ko jaldi dhundhna.

# %% [markdown]
# # RAG Mein Kya Hota Hai?
#
# After chunking:
#
# Chunk 1,
# Chunk 2,
# Chunk 3,
#
# Embedding banti hai:
#
# Chunk 1
# ↓
# [0.12, 0.45, 0.89]
#
# Chunk 2
# ↓
# [0.78, 0.21, 0.56]
#
# Ab in vectors ko kahin store karna padega.
#
# Yehi Vector Store karta hai.
#
# Chunks
#    +
# Vectors
#    ↓
# Vector Store

# %% [markdown]
# # (**Vector Store ek smart database hai jo embeddings (vectors) ko store karta hai aur user ke question se milte-julte chunks ko bahut fast retrieve karta hai.**)

# %% [markdown]
# #  Full Rag WorkFlow
#
# PDF
#  ↓
# Loader
#  ↓
# Document
#  ↓
# Text Splitter
#  ↓
# Chunks
#  ↓
# Embeddings
#  ↓
# ═══════════════
# VECTOR STORE
# ═══════════════
#  ↓
#
# User Question
#  ↓
# Question Embedding
#  ↓
# Similarity Search
#  ↓
# Relevant Chunks
#  ↓
# LLM
#  ↓
# Answer

# %% [markdown]
# # Embedding
#
# Embedding RAG ka heart hai. Agar embedding samajh gaye, to Vector Store aur Retrieval bhi samajh aa jayega.
#
# # Embedding Kya Hai?
#
# Simple definition:
#
# Embedding text ko numbers (vectors) mein convert karne ka tarika hai, taaki computer uska meaning samajh sake.

# %% [markdown]
# # Vector Store Key Features
#
# # 1. Vector Storage
#
# Sabse pehla kaam:
#
# Text
#  ↓
# Embedding
#  ↓
# Vector
#  ↓
# Store
#
# Example:
#
# "Python is used in AI"
#
# ↓
#
# [0.12, 0.45, 0.89 ...]
#
# Vector Store in vectors ko save karta hai.

# %% [markdown]
# # 2. Similarity Search
#
# Sabse important feature.
#
# User:
#
# Tell me about Python
#
# Vector Store compare karega:
#
# Question Vector
#
# vs
#
# Stored Vectors
#
# Aur sabse similar chunks nikal dega.

# %% [markdown]
# # 3. Fast Retrieval
#
# 10 lakh chunks ho sakte hain.
#
# Vector Store special indexing use karta hai.
#
# Isliye:
#
# Search Time
#
# Milliseconds
#
# mein result mil jata hai.

# %% [markdown]
# # 4. Semantic Search
#
# Ye keyword search nahi karta.
#
# Ye meaning search karta hai.
#
# Example:
#
# Document:
#
# Dogs are loyal pets
#
# User:
#
# Tell me about puppies
#
# Keyword same nahi hai.
#
# Lekin:
#
# Dog ≈ Puppy
#
# Meaning similar hai.
#
# Vector Store relevant chunk la sakta hai.

# %% [markdown]
# # 5. Metadata Filtering
#
# Chunk ke saath extra information bhi store kar sakte ho.
#
# Example:
#
# {
#   "source": "policy.pdf",
#   "department": "HR",
#   "year": 2025
# }
#
# Search:
#
# Only HR documents
#
# Ya
#
# Only 2025 documents

# %% [markdown]
# # 6. Indexing
#
# Special indexes banata hai.
#
# Jaise library mein catalog hota hai.
#
# Books
#  ↓
# Catalog
#  ↓
# Fast Search
#
# Waise:
#
# Vectors
#  ↓
# Index
#  ↓
# Fast Search

# %% [markdown]
# # 7. Scalability
#
# Handle kar sakta hai:
#
# 100 chunks
#
# 1000 chunks
#
# 1 Million chunks
#
# 10 Million chunks
#
# Data badhne par bhi kaam karta rehta hai.

# %% [markdown]
# # 8. Top-K Retrieval
#
# User question ke liye sirf best chunks laata hai.
#
# Example:
#
# 10000 chunks
#
# ↓
#
# Top 3 chunks
#
# Ya
#
# Top 5 chunks

# %% [markdown]
# # Vector Store vs Vector Database
#
# Vector Store
# =
# Vector storage + search system
#
# Vector Database
# =
# Complete database built for vectors

# %% [markdown]
# # Vector Store
#
# Vector Store ek smart store room hai jahan AI information ko numbers (vectors) ki form mein rakhkar jaldi se relevant data dhundh sakta hai.
#
# # Example
#
# Socho tumhare paas 1000 notes hain.
#
# Vector Store ka kaam:
#
# Notes Store Karna
#        +
# Sahi Note Jaldi Dhundhna

# %% [markdown]
# # Vector Database
#
# Vector Database ek poori smart library hai jo vectors ko store karne ke saath search, filtering, security aur large-scale management bhi karti hai.
#
# Example
#
# Socho:
#
# Vector Store
# =
# Ek cupboard
#
# Lekin:
#
# Vector Database
# =
# Puri library
#
# Jisme:
#
# Books store hoti hain
# Search hota hai
# Categories hoti hain
# Security hoti hai
# Bahut saare users use kar sakte hain

# %% [markdown]
# # Vector Store in LangChain Kya Hai?
#
# Embeddings Store karta hai
#         +
# Similarity Search karta hai
#
# # Simple words:
#
# Vector Store wo jagah hai jahan chunks ke embeddings save hote hain aur baad mein relevant chunks dhunde jaate hain.

# %% [markdown]
# # LangChain  Popular Vector Stores
#
# # 1. FAISS
#
# Features:
#
# Local Machine
#
# Fast
#
# Free
#
# No Cloud Required
#
# # 2. Chroma
#
# Features:
#
# Easy Setup
#
# Persistent Storage
#
# Popular for RAG
#
# # 3. Pinecone
#
# Cloud based.
#
# Production Projects
#
# Large Scale Systems
#
# # 4. Weaviate
#
# Enterprise level.
#
# # 5. Qdrant
#
# Modern vector database.

# %% [markdown]
# # Code

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-proj-"

# %%
# !pip install langchain chromadb openai tiktoken pypdf langchain_openai langchain-community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 853.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 41.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.0/346.0 kB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.6/99.6 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 62.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 17.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 62.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
# Out:
# /tmp/ipykernel_2043/398303453.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import Chroma

# %%
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store = Chroma(
    embedding_function=OpenAIEmbeddings(),
    persist_directory='my_chroma_db',
    collection_name='sample'
)
# Out:
# /tmp/ipykernel_2043/697003433.py:1: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   vector_store = Chroma(

# %%
# add documents
vector_store.add_documents(docs)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_2043/838592945.py in <cell line: 0>()
#       1 # add documents
# ----> 2 vector_store.add_documents(docs)
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/vectorstores/base.py in add_documents(self, documents, **kwargs)
#     256             texts = [doc.page_content for doc in documents]
#     257             metadatas = [doc.metadata for doc in documents]
# --> 258             return self.add_texts(texts, metadatas, **kwargs)
#     259         msg = (
#     260             f"`add_documents` and `add_texts` has not been implemented "
#
# /usr/local/lib/python3.12/dist-packages/langchain_community/vectorstores/chroma.py in add_texts(self, texts, metadatas, ids, **kwargs)
#     275         texts = list(texts)
#     276         if self._embedding_function is not None:
# ...

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])

# %%
# search documents
vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=2
)

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a bowler?',
    k=2
)

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)

# %%
# update documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='09a39dc6-3ba6-4ea7-927e-fdda591da5e4', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])

# %%
# delete document
vector_store.delete(ids=['09a39dc6-3ba6-4ea7-927e-fdda591da5e4'])

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': [],
#  'embeddings': array([], dtype=float64),
#  'documents': [],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': []}
